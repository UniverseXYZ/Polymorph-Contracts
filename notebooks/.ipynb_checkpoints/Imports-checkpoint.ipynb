// %%
const env = require('dotenv').config();

const { ethers } = require("ethers");

// %%
import mainnetABI from './abis/mainnet_ABI.json';
// Out:
// 1:24 - Cannot find module './abis/mainnet_ABI.json' or its corresponding type declarations.

// %%
const polymorphsMainNet = "0x1cBB182322Aee8ce9F4F1f98d7460173ee30Af1F"

// %%
const mainnet = "mainnet";
const providerMainnet= ethers.getDefaultProvider(mainnet, {
    infura: env.parsed.INFURA_API_KEY
});

// %%
const polyMainnetInst = new ethers.Contract(polymorphsMainNet, mainnetABI, providerMainnet);

// %%
polyMainnetInst
// Out:
// Contract {
//   interface: Interface {
//     fragments: [
//       [ConstructorFragment], [EventFragment],    [EventFragment],
//       [EventFragment],       [EventFragment],    [EventFragment],
//       [EventFragment],       [EventFragment],    [EventFragment],
//       [EventFragment],       [EventFragment],    [EventFragment],
//       [EventFragment],       [EventFragment],    [EventFragment],
//       [EventFragment],       [EventFragment],    [EventFragment],
//       [FunctionFragment],    [FunctionFragment], [FunctionFragment],
//       [FunctionFragment],    [FunctionFragment], [FunctionFragment],
//       [FunctionFragment],    [FunctionFragment], [FunctionFragment],
//       [FunctionFragment],    [FunctionFragment], [FunctionFragment],
//       [FunctionFragment],    [FunctionFragment], [FunctionFragment],
//       [FunctionFragment],    [FunctionFragment], [FunctionFragment],
//       [FunctionFragment],    [FunctionFragment], [FunctionFragment],
// ...
